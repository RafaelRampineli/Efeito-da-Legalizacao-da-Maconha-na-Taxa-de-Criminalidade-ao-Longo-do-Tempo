# %% [markdown]
# <strong><b><font size="5">Análise Estatística e Modelagem Preditiva de Séries Temporais - Em Python</font></b></strong>

# %% [markdown]
# <strong><b><font size="5">Projeto Final do Curso - Parte 1</font></b></strong>
#
# <strong><b><font size="4">Qual o Efeito da Legalização da Maconha na Taxa de Criminalidade ao Longo do Tempo?</font></b></strong>

# %% [markdown]
# ### Carregando os Pacotes Usados Neste Jupyter Notebook

# %%
# Comando para atualizar um pacote no terminal ou prompt de comando:
# pip install -U {nome_pacote}

# Para instalar a versão exata de um pacote:
# pip install {nome_pacote}=={versão_desejada}

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook, se necessário.

# %%
# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %% [markdown]
# Os pacotes abaixo serão os pacotes que iremos utilizar para extrair os dados sobre lojas que vendem maconha legalizada.

# %%
# Instala o pacote yelp
# !pip install -q yelp

# %%
# Instala o pacote yelpapi
# !pip install -q yelpapi

# %%
# As novas versões do Pandas e Matplotlib trazem diversas mensagens de aviso ao desenvolvedor. Vamos desativar isso.
import sys
import warnings
import matplotlib.cbook
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=matplotlib.cbook.mplDeprecation)

# Imports para manipulação de dados
import re
import json
import time
import numpy as np
import pandas as pd
from yelp.client import Client
from yelpapi import YelpAPI

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark --iversions
# Out:
# json       2.0.9
# re         2.2.1
# pandas     1.0.4
# numpy      1.18.4
# matplotlib 3.2.1

# %% [markdown]
# ### Extração e Limpeza dos Dados - Dataset 1
#
# Vamos coletar os dados de três fontes diferentes e vamos começar pelo <a href="https://www.yelp.com/">Yelp</a>.
#
# O Yelp é serviço que contém avaliações (reviews) e informações sobre empresas em várias regiões do mundo.
#
# Objetivo: Buscar as lojas de venda de maconha legalizada (chamadas dispensários) na região de Los Angeles, e então, vamos cruzar esses dados com a taxa de crimes e prisões nas mesmas regiões, além de dados sobre escolas.

# %% [markdown]
# ###### Observação importante:
#
# Para usar o Yelp, você precisa instalar os pacotes yelp e yelpapi (Feito acima). Depois disso, você deve acessar os endereços abaixo, criar sua conta Yelp e então criar sua app para obter a API de acesso.
#
# Aqui tem os detalhes da API: https://www.yelp.com/developers/documentation/v3/get_started
#
# E aqui o cadastro da app: https://www.yelp.com/developers/documentation/v3/authentication
#
# Após criar sua conta, será necessário a confirmação por e-mail antes de criar o app. Assim que o app é criada, é gerada uma API (uma chave de acesso), coloque a API na célula abaixo onde está 'Minha_api_key'.
#
# ###### Não é possível seguir adiante se você não criar sua API.
#
# ###### Existe um limite de 5000 chamadas diárias da API na conta gratuita. Se ultrapassar o limite diário, sua conta pode ser bloqueada. (Informação obtida na própria API).

# %%
# Aqui você deve incluir sua API Yelp
minha_api = "Minha_api_Key"

# %%
# Com a API definida, criamos um cliente de acesso
cliente_acesso = Client(minha_api)

# %% [markdown]
# Função para formatar o arquivo retornado com as consultas da API e gerar um arquivo de log da execução (histórico).

# %%
def formata_arquivo(file_path, 
                    logfile = './dados/arquivo_log.txt',  
                    file_description = None): 
   
    # Com o nome completo do arquivo, aplicamos expressões regulares para a limpeza
    # Aqui ajustamos a extensão do arquivo
    try:
        ext = re.search('(?<!^)(?<!\.)\.(?!\.)', file_path).start() 
    except:
        raise NameError('Digite um caminho de onde o arquivo pode ser encontrado.') 
    
    # Com o nome completo do arquivo, aplicamos expressões regulares para a limpeza
    # Aqui ajustamos timestamp para o nome do arquivo
    try:
        stamp = re.search('(?<!^)(?<!\.)[a-z]+_[a-z]+(?=\.)', file_path).start()
    except:
        raise NameError('Digite um caminho de onde o arquivo pode ser encontrado.') 
        
    # Formata o nome do arquivo adicionando o timestamp
    formatted_name = f'{file_path[:stamp]}{round(time.time())}_{file_path[stamp:]}' 
    
    # Se não tiver descrição no arquivo, adicionamos uma
    if not file_description:
        file_description = f'Arquivo gerado em: {time.asctime(time.gmtime(round(time.time())))}'
        
    # Abrimos o arquivo de log e gravamos o arquivo de dados formatado e a descrição
    with open(logfile, 'a+') as f:
        f.write(f'{formatted_name}: {file_description}\n')
        
    # Retornamos o arquivo de dados formatado e a descrição
    return formatted_name, file_description

# %% [markdown]
# Função de busca das lojas que vendem maconha legalizada em Los Angeles

# %%
# n_exec : numero de execuções que será realizada
# size: quantos registros serão retornados para cada busca dentro da API
def busca_yelp(category, location, offset_number = 0, n_exec = 20, size = 50):
    
    # API
    yelp_api = YelpAPI(minha_api)
    
    # Registro do último resultado
    last_result = round(time.time())
    
    # Lista para gravar os resultados
    resultados = []
        
    # Inicializa o número de loops
    loops = 0
    
    # Inicializa o número de execuções
    run = 1
    
    # Inicializa o offset
    offset_count = offset_number
   
    # Loop para retonar os dados
    while loops < n_exec:
        
        print(f'Executando a busca: {run}')
        
        # Fazendo a consulta
        posts = yelp_api.search_query(categories = category, 
                                      location = location, 
                                      offset = offset_count, 
                                      limit = size) 
            
        # Posts ligados a business
        resultados.extend(posts['businesses'])
        
        # Incrementa o número de loops
        loops += 1
        
        # Incrementa o offset para avançar na busca durante as iterações
        offset_count += 50
        
        # Aguarda 3 segundos para executar a próxima consulta
        time.sleep(3) 
        
        # Incrementa o número de execuções
        run += 1
       
    # Finalizado o loop, vamos retornar o nome do arquivo formatado e a descrição
    formatted_name, file_description = formata_arquivo(file_path =f'./arquivo_{category}.json')
    
    global formatted_name_return 
    formatted_name_return = formatted_name
    # Abrimos o arquivo formatado e fazemos o dump (gravação) dos resultados da consulta em formato JSON
    with open(formatted_name, 'w+') as f:
        json.dump(resultados, f)
    
    print(f'\nConsulta concluída. Total de lojas encontradas: {len(resultados)} {category} .')
    
    # return print(f'\nEsse foi o último timestamp {round(time.time())}.')

# %%
# Executamos a busca com o tipo de estabelecimento e a cidade
busca_yelp('cannabisdispensaries', 'los angeles', n_exec = 1, size = 50)
# Out:
# Executando a busca: 1
#
# Consulta concluída. Total de lojas encontradas: 50 cannabisdispensaries .

# %%
# Abre o arquivo JSON para leitura e geração da lista final
with open(f'{formatted_name_return}', 'r') as f:
    lista_lojas_la = json.load(f)

# %%
# Vamos visualizar um registro da lista
lista_lojas_la[5]
# Out:
# {'id': '_PVsgnMe_ut8BcQSVhAVgw',
#  'alias': 'herb-los-angeles-3',
#  'name': 'HERB',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HSw89Daf0Tmxf7aUAXRC6g/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/herb-los-angeles-3?adjust_creative=nKnicr6HZ6bapdL17PUcuQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nKnicr6HZ6bapdL17PUcuQ',
#  'review_count': 96,
#  'categories': [{'alias': 'cannabis_clinics', 'title': 'Cannabis Clinics'},
#   {'alias': 'cannabisdispensaries', 'title': 'Cannabis Dispensaries'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 34.0434989929199, 'longitude': -118.250205993652},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '',
#   'address2': None,
#   'address3': '',
#   'city': 'Los Angeles',
#   'zip_code': '90014',
#   'country': 'US',
#   'state': 'CA',
#   'display_address': ['Los Angeles, CA 90014']},
#  'phone': '+18444372213',
#  'display_phone': '(844) 437-2213',
#  'distance': 6707.647988501463}

# %% [markdown]
# Vamos organizar e limpar esses dados.

# %%
# Essa função vai organizar os dados da lista de lojas em um dataframe do pandas
def organiza_dados(lista_lojas):    
    # Converte a lista de lojas em dataframe do pandas
    df = pd.DataFrame(lista_lojas)
    
    # Lista com os nomes de colunas que nos interessam
    col_list = ['name', 'is_closed', 'url', 'rating', 'coordinates', 'location', 'price', 'review_count']
    
    # Define a lista de colunas acima como nome de cada coluna
    df = df[col_list]

    return df

# %%
# Aplica a função e cria nosso dataframe
df_lojas = organiza_dados(lista_lojas_la)

# %%
# Shape
df_lojas.shape
# Out:
# (50, 8)

# %%
# Visualizamos uma amostra de dados
df_lojas.head()
# Out:
#                                  name  is_closed  \
# 0      California Caregivers Alliance      False
# 1                           Herbarium      False
# 2                             Kushfly      False
# 3              Green Earth Collective      False
# 4  MedMen Venice Beach - Abbot Kinney      False
#
#                                                  url  rating  \
# 0  https://www.yelp.com/biz/california-caregivers...     4.5
# 1  https://www.yelp.com/biz/herbarium-west-hollyw...     4.5
# 2  https://www.yelp.com/biz/kushfly-los-angeles-5...     4.0
# 3  https://www.yelp.com/biz/green-earth-collectiv...     4.5
# 4  https://www.yelp.com/biz/medmen-venice-beach-a...     4.5
#
#                                         coordinates  \
# 0  {'latitude': 34.08235, 'longitude': -118.272037}
# 1    {'latitude': 34.08853, 'longitude': -118.3446}
# 2  {'latitude': 34.127617, 'longitude': -118.34671}
# 3   {'latitude': 34.12247, 'longitude': -118.21067}
# 4   {'latitude': 33.99088, 'longitude': -118.46783}
#
#                                             location price  review_count
# 0  {'address1': '2815 W Sunset Blvd', 'address2':...   NaN           252
# 1  {'address1': '979 N La Brea Ave', 'address2': ...    $$           263
# 2  {'address1': '', 'address2': None, 'address3':...    $$           248
# 3  {'address1': '4801 York Blvd', 'address2': '',...    $$           195
# 4  {'address1': '1310 Abbot Kinney Blvd', 'addres...    $$           173

# %% [markdown]
# Vamos extrair a lista de latitudes e longitudes de cada loja, pois usaremos geolocalização mais tarde em outra etapa.

# %%
# Realiza o acesso através do index e navega na coluna coordinates propriedade latitude

# Extrai a lista de latitudes
lista_latitude = [lista_lojas_la[i]['coordinates']['latitude'] for i in range(len(lista_lojas_la))]

# Extrai a lista de longitudes
lista_longitude = [lista_lojas_la[i]['coordinates']['longitude'] for i in range(len(lista_lojas_la))]

# %%
# Adiciona latitude e longitude ao dataframe df_lojas
df_lojas['latitude'] = lista_latitude
df_lojas['longitude'] = lista_longitude

# %%
# Visualizamos uma amostra de dados
df_lojas.head()
# Out:
#                                  name  is_closed  \
# 0      California Caregivers Alliance      False
# 1                           Herbarium      False
# 2                             Kushfly      False
# 3              Green Earth Collective      False
# 4  MedMen Venice Beach - Abbot Kinney      False
#
#                                                  url  rating  \
# 0  https://www.yelp.com/biz/california-caregivers...     4.5
# 1  https://www.yelp.com/biz/herbarium-west-hollyw...     4.5
# 2  https://www.yelp.com/biz/kushfly-los-angeles-5...     4.0
# 3  https://www.yelp.com/biz/green-earth-collectiv...     4.5
# 4  https://www.yelp.com/biz/medmen-venice-beach-a...     4.5
#
#                                         coordinates  \
# 0  {'latitude': 34.08235, 'longitude': -118.272037}
# 1    {'latitude': 34.08853, 'longitude': -118.3446}
# 2  {'latitude': 34.127617, 'longitude': -118.34671}
# 3   {'latitude': 34.12247, 'longitude': -118.21067}
# 4   {'latitude': 33.99088, 'longitude': -118.46783}
#
#                                             location price  review_count  \
# 0  {'address1': '2815 W Sunset Blvd', 'address2':...   NaN           252
# 1  {'address1': '979 N La Brea Ave', 'address2': ...    $$           263
# 2  {'address1': '', 'address2': None, 'address3':...    $$           248
# 3  {'address1': '4801 York Blvd', 'address2': '',...    $$           195
# 4  {'address1': '1310 Abbot Kinney Blvd', 'addres...    $$           173
#
#     latitude   longitude
# 0  34.082350 -118.272037
# 1  34.088530 -118.344600
# 2  34.127617 -118.346710
# 3  34.122470 -118.210670
# 4  33.990880 -118.467830

# %%
# Como já temos os dados de latitude e longitude, a coluna location com o endereço completo e a coluna coordinates 
# podem ser removidas do dataframe.
df_lojas.drop('location', axis = 1, inplace = True)

# E removemos a coluna com as coordenadas
df_lojas.drop(labels = ['coordinates'], axis = 1, inplace = True)

# %%
# Criando uma nova coluna location contendo uma tupla com latitude e longitude
df_lojas['location'] = list(zip(df_lojas['latitude'], df_lojas['longitude']))

# %%
# Conferimos o shape
df_lojas.shape
# Out:
# (50, 9)

# %%
# Visualizamos uma amostra de dados
df_lojas.head()
# Out:
#                                  name  is_closed  \
# 0      California Caregivers Alliance      False
# 1                           Herbarium      False
# 2                             Kushfly      False
# 3              Green Earth Collective      False
# 4  MedMen Venice Beach - Abbot Kinney      False
#
#                                                  url  rating price  \
# 0  https://www.yelp.com/biz/california-caregivers...     4.5   NaN
# 1  https://www.yelp.com/biz/herbarium-west-hollyw...     4.5    $$
# 2  https://www.yelp.com/biz/kushfly-los-angeles-5...     4.0    $$
# 3  https://www.yelp.com/biz/green-earth-collectiv...     4.5    $$
# 4  https://www.yelp.com/biz/medmen-venice-beach-a...     4.5    $$
#
#    review_count   latitude   longitude                 location
# 0           252  34.082350 -118.272037  (34.08235, -118.272037)
# 1           263  34.088530 -118.344600    (34.08853, -118.3446)
# 2           248  34.127617 -118.346710  (34.127617, -118.34671)
# 3           195  34.122470 -118.210670   (34.12247, -118.21067)
# 4           173  33.990880 -118.467830   (33.99088, -118.46783)

# %% [markdown]
# ##### Finalizamos a limpeza do nosso primeiro dataset. Vamos salvá-lo em disco para ser possível carregar depois nas etapas seguintes.

# %%
# Salva o dataframe de lojas em um arquivo csv
df_lojas.to_csv('dados/df_lojas.csv')

# %% [markdown]
# ### Extração e Limpeza dos Dados - Dataset 2
#
# O segundo dataset é sobre os crimes que ocorreram em Los Angeles entre 2010 e 2019. O dataset já está disponivel mas caso queira fazer o download direto da fonte ou estudar o dicionário de dados, siga os passos abaixo:
#
# - 1- Acesse o endereço: https://data.lacity.org/
#
# - 2- Descendo um pouco na página, use a caixa de busca de datasets e pesquise por "Crime Data".
#
# - 3- O que você precisa deve ser a primeira opção: "Crime Data from 2010 to 2019". Clique no nome do dataset.
#
# - 4- Na página seguinte clique no botão azul "View Data". Clique então em "Export" - "Download" - "CSV".
#
# - 5- Coloque o arquivo na pasta dados no mesmo diretório onde está este Jupyter Notebook. O arquivo tem mais de 2 milhões de registros.

# %%
# Vamos carregar o arquivo com os crimes em LA entre 2010 e 2019
df_crimes = pd.read_csv('dados/Crime_Data_from_2010_to_2019.csv')

# %%
# Shape
df_crimes.shape
# Out:
# (2114238, 28)

# %%
# Visualizamos uma amostra de dados
df_crimes.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 2                          OTHER MISCELLANEOUS CRIME  ...     IC
# 3                           VIOLATION OF COURT ORDER  ...     IC
# 4                                    RAPE, ATTEMPTED  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    900.0      NaN       NaN      NaN
# 1   Invest Cont    740.0      NaN       NaN      NaN
# 2   Invest Cont    946.0      NaN       NaN      NaN
# 3   Invest Cont    900.0    998.0       NaN      NaN
# 4   Invest Cont    122.0      NaN       NaN      NaN
#
#                                   LOCATION                     Cross Street  \
# 0   300 E  GAGE                         AV                              NaN
# 1          SEPULVEDA                    BL  MANCHESTER                   AV
# 2  1300 E  21ST                         ST                              NaN
# 3          CAHUENGA                     BL  HOLLYWOOD                    BL
# 4          8TH                          ST  SAN PEDRO                    ST
#
#        LAT       LON
# 0  33.9825 -118.2695
# 1  33.9599 -118.3962
# 2  34.0224 -118.2524
# 3  34.1016 -118.3295
# 4  34.0387 -118.2488
#
# [5 rows x 28 columns]

# %%
# Substituindo nomes de colunas com espaço por underline, para poder usar os nomes das colunas como filtro de indexação.
df_crimes.columns = [column.lower().replace(' ', '_') for column in df_crimes.columns]

# %%
# Verificando se existem valores nulos no dataset
df_crimes.isnull().sum()
# Out:
# dr_no                   0
# date_rptd               0
# date_occ                0
# time_occ                0
# area_                   0
# area_name               0
# rpt_dist_no             0
# part_1-2                0
# crm_cd                  0
# crm_cd_desc             0
# mocodes            227959
# vict_age                0
# vict_sex           196652
# vict_descent       196699
# premis_cd              53
# premis_desc           187
# weapon_used_cd    1404139
# weapon_desc       1404140
# status                  3
# status_desc             0
# crm_cd_1               10
# crm_cd_2          1975051
# crm_cd_3          2110747
# crm_cd_4          2114134
# location                0
# cross_street      1758896
# lat                     0
# lon                     0
# dtype: int64

# %% [markdown]
# Vamos fazer uma limpeza geral nos dados removendo colunas que não serão utilizadas.

# %% [markdown]
# Removendo colunas que não serão necessárias.
# ###### É possível obter o dicionário de dados na página para download do arquivo para informações sobre cada coluna.

# %%
df_crimes.drop(labels = ['crm_cd', 'crm_cd_1', 'crm_cd_2', 'crm_cd_3', 'crm_cd_4',
                         'premis_cd', 'premis_desc', 'vict_descent', 'vict_sex', 'status',
                         'dr_no', 'area_', 'date_rptd', 'rpt_dist_no', 'part_1-2',
                         'mocodes', 'cross_street', 'weapon_used_cd',
                         'status_desc', 'time_occ', 'vict_age'
                        ], 
               axis = 1, 
               inplace = True
              )

# %%
# A coluna weapon_desc vamos manter e preencher valores NA com 'desconhecido'
df_crimes.weapon_desc.fillna('desconhecido', inplace = True)

# %%
# Vamos checar se ainda sobrou valor nulo
df_crimes.isnull().sum()
# Out:
# date_occ       0
# area_name      0
# crm_cd_desc    0
# weapon_desc    0
# location       0
# lat            0
# lon            0
# dtype: int64

# %%
# Tipos de dados
df_crimes.dtypes
# Out:
# date_occ        object
# area_name       object
# crm_cd_desc     object
# weapon_desc     object
# location        object
# lat            float64
# lon            float64
# dtype: object

# %% [markdown]
# Variáveis ajustadas e nenhum dado missing.

# %%
# Visualizamos uma amostra de dados
df_crimes.head()
# Out:
#                  date_occ  area_name  \
# 0  02/20/2010 12:00:00 AM     Newton
# 1  09/12/2010 12:00:00 AM    Pacific
# 2  08/09/2010 12:00:00 AM     Newton
# 3  01/05/2010 12:00:00 AM  Hollywood
# 4  01/02/2010 12:00:00 AM    Central
#
#                                          crm_cd_desc  \
# 0                           VIOLATION OF COURT ORDER
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 2                          OTHER MISCELLANEOUS CRIME
# 3                           VIOLATION OF COURT ORDER
# 4                                    RAPE, ATTEMPTED
#
#                                       weapon_desc  \
# 0                                    desconhecido
# 1                                    desconhecido
# 2                                    desconhecido
# 3                                        HAND GUN
# 4  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
#
#                                   location      lat       lon
# 0   300 E  GAGE                         AV  33.9825 -118.2695
# 1          SEPULVEDA                    BL  33.9599 -118.3962
# 2  1300 E  21ST                         ST  34.0224 -118.2524
# 3          CAHUENGA                     BL  34.1016 -118.3295
# 4          8TH                          ST  34.0387 -118.2488

# %%
# Salva o dataframe de crimes em um arquivo csv
df_crimes.to_csv('dados/df_crimes.csv')

# %% [markdown]
# ### Extração e Limpeza dos Dados - Dataset 3
#
# O terceiro dataset é referente as prisões em LA. Os dados podem ser obtidos com o mesmo procedimento descrito no Dataset 2, com apenas uma mudança:
#
# - 1- Acesse o endereço: https://data.lacity.org/
#
# - 2- Descendo um pouco na página, use a caixa de busca de datasets e pesquise por "Arrests".
#
# - 3- O que você precisa deve ser a primeira opção: "Arrest Data from 2010 to Present". Clique no nome do dataset.
#
# - 4- Na página seguinte clique no botão azul "View Data". Clique então em "Export" - "Download" - "CSV".
#
# - 5- Coloque o arquivo na pasta dados no mesmo diretório onde está este Jupyter Notebook. O arquivo tem mais de 1 milhão de registros.
#
# O arquivo csv contém aproximadamente 1,2 milhão de prisões. O conjunto de dados é fornecido pelo Departamento de Polícia de Los Angeles (LAPD). Cada linha é o registro de um detido e cada coluna contém detalhes sobre o incidente da prisão. Para os fins deste projeto, examinaremos apenas as detenções relacionadas à maconha aplicando um filtro à `Charge Description` se a coluna contiver a palavra `marijuana` (maconha em inglês).
#
# Calcularemos então a distância entre cada prisão e dispensário de maconha (loja legalizada) e examinaremos o número de prisões por maconha a menos de 800 quilômetros de um dispensário a cada ano (faremos isso na Análise Exploratória).
#
# #### Não é necessário o Download dos dados, já está disponível.

# %%
# Vamos carregar o arquivo com as prisoes em LA de 2010 ao momento presente (Data que foi extraído)
df_prisoes = pd.read_csv('dados/Arrest_Data_from_2010_to_Present.csv')

# %%
# Shape
df_prisoes.shape
# Out:
# (1350103, 17)

# %%
# Visualizamos uma amostra de dados
df_prisoes.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  200110044  03/27/2020  2125.0        1    Central                 142   20
# 1  200110045  04/01/2020  1800.0        1    Central                 166   44
# 2  200110271  03/08/2020  1545.0        1    Central                 166   61
# 3  201908605  04/08/2020  1530.0       19    Mission                1987   33
# 4  191811472  05/03/2019  1700.0       18  Southeast                1802   23
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            W               13.0      Prostitution/Allied
# 1        F            H               18.0               Drunkeness
# 2        M            B               18.0               Drunkeness
# 3        M            H                NaN                      NaN
# 4        F            B                NaN                      NaN
#
#   Arrest Type Code       Charge     Charge Description  \
# 0                M     647(B)PC           PROSTITUTION
# 1                M  41.27(C)LAM  DRINKING IN PUBLIC***
# 2                M  41.27(C)LAM  DRINKING IN PUBLIC***
# 3                M   25620(A)BP                    NaN
# 4                M    653.22 PC                    NaN
#
#                                   Address                     Cross Street  \
# 0  400 S  FIGUEROA                     ST                              NaN
# 1         WINSTON                      ST  SAN PEDRO                    ST
# 2                                     6TH                       SAN JULIAN
# 3                                 WOODMAN                            CHASE
# 4                                    91ST                         FIGUEROA
#
#                Location
# 0   (34.0535, -118.256)
# 1  (34.0421, -118.2469)
# 2  (34.0428, -118.2461)
# 3   (34.228, -118.4344)
# 4  (33.9543, -118.2827)

# %%
# Tipos de dados
df_prisoes.dtypes
# Out:
# Report ID                     int64
# Arrest Date                  object
# Time                        float64
# Area ID                       int64
# Area Name                    object
# Reporting District            int64
# Age                           int64
# Sex Code                     object
# Descent Code                 object
# Charge Group Code           float64
# Charge Group Description     object
# Arrest Type Code             object
# Charge                       object
# Charge Description           object
# Address                      object
# Cross Street                 object
# Location                     object
# dtype: object

# %%
# Vamos converter a coluna 'Arrest Date' de string (object) para Datetime, para facilitar a manipulação
df_prisoes['Arrest Date'] = pd.to_datetime(df_prisoes['Arrest Date'])

# %%
# Vamos usar expressões regulares para transformar a coluna Location de tupla em lista para facilitar a indexação na hora 
# de separar em 2 novas colunas.
df_prisoes['Location'] = df_prisoes['Location'].map(lambda x: re.sub('[(),°]', '', x)).str.split()

# %%
# Vamos criar as variáveis latitude e longitude
df_prisoes['latitude'] = df_prisoes['Location'].map(lambda x: x[0])
df_prisoes['longitude'] = df_prisoes['Location'].map(lambda x: x[1])

# %%
# Convertemos latitude e longitude para o tipo float para não perder a precisão
df_prisoes['latitude'] = df_prisoes['latitude'].map(lambda x: float(x))
df_prisoes['longitude'] = df_prisoes['longitude'].map(lambda x: float(x))

# %%
# Convertemos os registros da coluna 'Charge Description' em string e minúsculo
df_prisoes['Charge Description'] = df_prisoes['Charge Description'].map(lambda x: str(x))
df_prisoes['Charge Description'] = df_prisoes['Charge Description'].map(lambda x: x.lower())

# %%
# Visualizamos uma amostra de dados
df_prisoes.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  200110044  2020-03-27  2125.0        1    Central                 142   20
# 1  200110045  2020-04-01  1800.0        1    Central                 166   44
# 2  200110271  2020-03-08  1545.0        1    Central                 166   61
# 3  201908605  2020-04-08  1530.0       19    Mission                1987   33
# 4  191811472  2019-05-03  1700.0       18  Southeast                1802   23
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            W               13.0      Prostitution/Allied
# 1        F            H               18.0               Drunkeness
# 2        M            B               18.0               Drunkeness
# 3        M            H                NaN                      NaN
# 4        F            B                NaN                      NaN
#
#   Arrest Type Code       Charge     Charge Description  \
# 0                M     647(B)PC           prostitution
# 1                M  41.27(C)LAM  drinking in public***
# 2                M  41.27(C)LAM  drinking in public***
# 3                M   25620(A)BP                    nan
# 4                M    653.22 PC                    nan
#
#                                   Address                     Cross Street  \
# 0  400 S  FIGUEROA                     ST                              NaN
# 1         WINSTON                      ST  SAN PEDRO                    ST
# 2                                     6TH                       SAN JULIAN
# 3                                 WOODMAN                            CHASE
# 4                                    91ST                         FIGUEROA
#
#                Location  latitude  longitude
# 0   [34.0535, -118.256]   34.0535  -118.2560
# 1  [34.0421, -118.2469]   34.0421  -118.2469
# 2  [34.0428, -118.2461]   34.0428  -118.2461
# 3   [34.228, -118.4344]   34.2280  -118.4344
# 4  [33.9543, -118.2827]   33.9543  -118.2827

# %%
# Shape
df_prisoes.shape
# Out:
# (1350103, 19)

# %% [markdown]
# Vamos extrair prisões relacionadas à maconha.
#
# **Obs: Maconha tem muitas denominações em inglês, mas nesses datasets está registrada como marijuana**.

# %%
# Vamos extrair os tipos de prisões distintos e colocar em uma lista ordenando por quantidade de registros.
lista_prisoes = list(df_prisoes['Charge Description'].value_counts().index.sort_values())

# %%
# Vamos colocar em minúsculo para usar os dados no mesmo padrão
lista_prisoes = [x.lower() for x in lista_prisoes]

# %%
# Tipos de prisões
lista_prisoes
# Out:
# ['290 viol post incarc',
#  '2nd degree burglary during earthquake/etc',
#  '< age 21 driving veh w/blood-alcohol .01+',
#  'abandon dog or cat',
#  'abandon/non-support child under 14 yrs',
#  'accept wager/hold bets',
#  'accepting a wager - hold bets/wagers',
#  'access card forgery',
#  'access computer and make copies',
#  'access computer to defraud/deceive/extort',
#  'access/delete computer data',
#  'accessory aftr fact-know fel crime/person',
#  'acquire access card in 4+ names > 12 mos',
#  'acquire access card in 4+names >12 mos',
#  'acquire access card known to be lost',
#  'acquire access card w/intent to defraud',
#  'acquire access card w/intent to use/sell',
#  'acqure access card account number',
#  'act as vehicle salesman w/o license',
#  'act unlawfully as auctioneer',
#  'acting as a look-out',
#  'ad 4 sale/etc recordg/etc w/o origin w/pr',
#  'administer/etc cntl subs to addict',
#  'adult school/molest pupils',
#  'adult sell/etc cntl sub/narcotic to mi',
#  'adult solicit/etc mi:viol cntl sub/narco',
#  'adult use force to coerce minor join gang',
#  'adulterate/sell adulteratd food/drugs/etc',
#  'advertise obscene matter depicting minor',
#  'advertising as optometrist',
#  'adw (renum-245(a)(1)pc / 245(a)(2)pc)',
#  'adw on po/fireman w/machinegun',
#  'adw on po/fireman w/semiautomatic',
#  'adw on school employee w/not firearm/gbi',
#  'adw po/fire-ftr w/mach gun/aslt weapon',
#  'adw po/fireman w/o firearm/gbi',
#  'adw w/firearm',
#  'adw w/machinegun/assault weapon',
#  'adw w/o firearm/gbi',
#  'adw w/semiautomatic rifle',
#  'adw, not firearm, w/gbi',
#  'aggravate battery by prisoner',
#  'aggravated arson',
#  'aggravated mayhem',
#  'aggravated sexl asslt/child-oral copulatn',
#  'aggravated sexual asslt/child - pc264.1',
#  'aggravated sexual asslt/child - pc289(a)',
#  'aggravated sexual asslt/child - sodomy',
#  'aggravated sexual asslt/child-pc261(a)(2)',
#  'aid/abet illegal exhibit of speed',
#  'aid/abet/engage in speed contest',
#  'aid/attempt escape parolee/prisonr/escape',
#  'aide/abet speed contest',
#  'aide/abet speed exhibitn',
#  'aim/etc laser pointer',
#  'alarm w/o permit',
#  'alchl bev lic permit minor consume alcohl',
#  'alcoholic bev lic permit alchl consmptn',
#  'alcoholic bev licensee poss unauth liq',
#  'alcoholic bev sales to intoxicated persns',
#  'alhambra municipal code',
#  'allow minor near drug paraphernalia',
#  'allow open container in passenger area',
#  "allow unlicensed driver 2 drive one's veh",
#  'allow vicious animal at large',
#  'allowing animal fights',
#  'alter medical record w/fraudulent intent',
#  'alter registration/license plates/etc',
#  'alter/change vehicle id number',
#  'alter/deface vin to sell or transfer',
#  'alter/etc firearm markings',
#  'alteration of tear gas weapon id mark',
#  'ammunition poss by enjoined gang member',
#  'amplified sound regulations',
#  'animal endangerment w/injury',
#  'annoy child after ill entry of inhab bldg',
#  'annoy/etc child -18 with prior',
#  'annoy/etc child after spec pr convictn',
#  'annoy/etc child under 18',
#  'annoy/molest child',
#  'annoy/molest child (r-1988)',
#  'annoy/molest child with prior conviction',
#  'annoy/molest children <18',
#  'annoy/molest person in ped subway',
#  'annoy/molet child with prior',
#  'annoying repeated phone calls residence',
#  'annoying/etc calls to 911',
#  'appropriate lost property',
#  'arcade w/o permit',
#  'arrange meeting w/minor w/prior',
#  'arrange/mtg w/minor for lewd behavior',
#  'arrest/detain w/o authority',
#  'arson',
#  'arson causing gbi',
#  'arson inhabited structure/property',
#  'arson of property',
#  'arson of structure or forest land',
#  'artesia municipal code',
#  'ask/take bribe fr violatr by po',
#  'aslt prsn:pub transp/etc',
#  'aslt:mayhem/rape/etc',
#  'assault by peace officer',
#  'assault dependent adult',
#  'assault elder adult',
#  'assault likely to produce gbi',
#  'assault on a police horse/dog',
#  'assault on child causing death',
#  'assault on custodial officer',
#  'assault on peace officer/firefighters/etc',
#  'assault on person',
#  'assault on public officials',
#  'assault on school district police officer',
#  'assault on school employee',
#  'assault on school/park property',
#  'assault on transportatn personel/passengr',
#  'assault p.o./emergency personnel/etc',
#  'assault result death of child under 8yr',
#  'assault to commit l or l act on child',
#  'assault to commit rape',
#  'assault w/caustic chemicals',
#  'assault w/firearm on po or fireman',
#  'assault w/intent',
#  'assault w/intent to commit other felony',
#  'assault w/stun gun or taser',
#  'assault w/stun gun/taser on po/firefightr',
#  'assault with deadly weapon person',
#  'assault/battery on school property',
#  'assault/battery: on school property',
#  'assault:peace officer/emergency personnel',
#  'assemble/maintain/place boobytrap device',
#  'assist act of indecent exposure',
#  'assist/etc false or fraud insurance claim',
#  'assist/solicit/etc insurance fraud',
#  'assisting in a lottery',
#  'atmpt-prev/dissuade wit/vict force/threat',
#  'att - arson inhabited structure/property',
#  'att -petty theft merchandise/library book',
#  'att -sodomy w/prsn<14 by prsn 10 yrs oldr',
#  'att disordr cond lodge,bldg/etc w/o cons',
#  'att inflict corp inj spouse/cohabitant',
#  'att obtain money/etc by false pretenses',
#  'att oral cop by use of force/injury',
#  'att petty theft w/pr petty/grand/auto/etc',
#  'att poss cntl sub w/sp pr',
#  'att remove/phone/telegraph/cable/power ln',
#  'att sex penetration: foreign object/force',
#  'att-oral cop w/prsn<14 by prsn 10yr oldr',
#  'attempt - aggravated mayhem',
#  'attempt - battery',
#  'attempt - bring stolen prop into state',
#  'attempt - burglary',
#  'attempt - burglary 1st degree',
#  'attempt - escape jail while fel pending',
#  'attempt - extortion',
#  'attempt - extortion - defined',
#  'attempt - extortion - punishment',
#  'attempt - false id to peace officer',
#  'attempt - forgery',
#  'attempt - hit and run property damage',
#  'attempt - kidnapping',
#  'attempt - kidnapping for child molesting',
#  'attempt - larceny',
#  'attempt - lynching - defined',
#  'attempt - mayhem',
#  'attempt - murder',
#  'attempt - oral copulation - defined',
#  'attempt - oral copulation act in concert',
#  'attempt - oral copulation,confine in jail',
#  'attempt - petty theft',
#  'attempt - poss controlled substance',
#  'attempt - poss narcotic cntl sub for sale',
#  'attempt - possession cntl subs for sale',
#  'attempt - rape by force/fear',
#  'attempt - robbery',
#  'attempt - robbery of common carrier',
#  'attempt - sell subs in lieu of cntl subs',
#  'attempt - sell subse in lieu of cntl subs',
#  'attempt - sell/furnish/etc marijuana',
#  'attempt - sodomy: act in concert w/force',
#  'attempt - take vehicle w/o consent',
#  'attempt -assault w/int to commit spec fel',
#  'attempt -defraud innkeeper nonpaymt <$400',
#  'attempt -theft: appropriate lost property',
#  'attempt -vandalism loss > $1,000 < $5,000',
#  'attempt adw no firearms/gbi',
#  'attempt adw on po/fireman w/o/firearm/gbi',
#  'attempt adw w/firearm',
#  'attempt aid in attempt to burn structure',
#  'attempt arson of property',
#  'attempt arson structure or forest land',
#  'attempt battery on peace officer',
#  'attempt burglary from vehicle',
#  'attempt caretaker commit lewd act',
#  'attempt commercial burglary',
#  'attempt crime w/great bodily harm',
#  'attempt disruptive entry of school',
#  "attempt drive without a driver's licence",
#  'attempt drunk driving',
#  'attempt felony poss controlled substance',
#  'attempt forcible oral copulation',
#  'attempt forge/make/usecard/defraud',
#  'attempt genital/anal penetration',
#  'attempt grand theft',
#  'attempt grand theft auto',
#  'attempt grand theft by threat',
#  'attempt grand theft firearm/etc',
#  'attempt grand theft person',
#  'attempt grand theft vehicle/vessel/etc',
#  'attempt grand theft, miscellaneous',
#  'attempt inflict bod harm/death adlt elder',
#  'attempt inflict injury on child',
#  'attempt kidnap in commission of carjack',
#  'attempt kidnap w/intent to rob',
#  'attempt kidnapping for ransom',
#  'attempt lewd/lascivious acts w/child < 14',
#  'attempt make/poss/utter fictitious instrmt',
#  'attempt mfg/etc false citizenxhip docmnts',
#  'attempt oral cop: w/vict unconsc of act',
#  'attempt oral copulation',
#  'attempt oral copulation of minor < 16 yrs',
#  'attempt perjury under oath',
#  'attempt petty theft',
#  'attempt poss of false registration',
#  'attempt poss/purchase cocaine base 4 sale',
#  'attempt possess controlled substance',
#  'attempt possession controlled substance',
#  'attempt rape - victim unconscious of act',
#  'attempt rape by use of drugs/intoxicants',
#  'attempt rape in concert w/force/violence',
#  'attempt rape victim incapable of consent',
#  'attempt receive known stolen property/etc',
#  'attempt receive stolen property >$950',
#  'attempt receiving stolen property<$400',
#  'attempt receiving stolen property>$400',
#  'attempt refuse to leave private property',
#  'attempt remove firearm from peace officer',
#  'attempt remove weapon from police officer',
#  'attempt remove/take firearm from p.o.',
#  'attempt residential burglary',
#  'attempt sodomy',
#  'attempt sodomy while confined in prison',
#  'attempt spousal rape w/force/fear/threat',
#  'attempt spousal rape,force/viol/fear/etc',
#  'attempt spousal rape,use drugs/intoxicant',
#  'attempt tampering w/vehicle',
#  'attempt terrorist threats',
#  'attempt theft elder/dependent adult $400+',
#  'attempt to deface property',
#  'attempt to destroy property $1000-',
#  'attempt to dissuade witness',
#  'attempt to inflict bodily injury',
#  'attempt to poss < 28.5 grams of marijuana',
#  'attempt to prev wit/victim give testimony',
#  'attempt to prevent/dissuade/victim from',
#  'attempt to remove firearm from po',
#  'attempt to resist arrest police officer',
#  'attempt to solicit sales of narcotics',
#  'attempt to torture/kill living animal',
#  'attempt touch intimate parts of another',
#  'attempt transport/sell cntl subs',
#  'attempt transport/sell cntld substance',
#  'attempt transport/sell narcotic/cntl subs',
#  'attempt unauthorized entry of property',
#  'attempt unlawful sex w/minor female',
#  'attempt use/under influence of cntl subs',
#  'attempt welfare fraud',
#  'attempt willful cruelty to child',
#  'attempt-robbery w/in publc veh-1st degree',
#  'attempt/aid to burn structure/forest/prop',
#  'attempt/escape prison w/o force/violence',
#  'attempted aggravated arson',
#  'attempted carjacking',
#  'attempted extortion',
#  'attempted identity theft',
#  'attempted lewed act on child 14 or 15 yrs',
#  'attempted murder',
#  'attempted pandering by encouraging',
#  'attempted poss of cntl subs paraphernalia',
#  'attempted robbery',
#  'attempted robbery - 2nd degree',
#  'attempted sodomy',
#  'attempted sodomy by use of force',
#  'attempted torture',
#  'attemptreceive known stolen property/etc',
#  'attorney pract/ad aftr suspend/disbared',
#  'attorney unlawful practice/advertise law',
#  'audible signaling devices',
#  'auto dealer/mfg transport w/o license',
#  'auto repair: maint/inspection of records',
#  'auto theft w/specific prior',
#  'automotive repair invoice fraud',
#  'avoid airport screening/inspection',
#  'avoid registration compliance',
#  'azusa municipal code',
#  'bailee tamper w/vehicle',
#  'bank/etc robbery',
#  'barbering or cosmetology w/o a license',
#  'batt ex-spouse/fiancee/persn w/dating rel',
#  'batt on schl employee/retaliation w/inj',
#  'batt prsn on school prop',
#  'batt prsn:pub transp/etc',
#  'batter person not inmate while in cust',
#  'battery',
#  'battery against sports official',
#  'battery by prisoner',
#  'battery gassing',
#  'battery gassing non-peace ofc. fel',
#  'battery of elder or dependent adult',
#  'battery of non-inmate by jail inmate',
#  'battery on custodial officer',
#  'battery on custodial officer/firefighter/',
#  'battery on noncohabitating former spouse',
#  'battery on p.o./emergency personel/etc',
#  'battery on peace officer',
#  'battery on person',
#  'battery on person on school property',
#  'battery on person on school/hosp/park/prop',
#  'battery on person with injury',
#  'battery on po/emergency personnel w/inj',
#  'battery on po/emergency personnel w/o inj',
#  'battery on school/prk/hospital grounds',
#  'battery on transportation worker',
#  'battery person not inmate while in cust',
#  'battery transportation personnel/passengr',
#  'battery w/gbi',
#  'battery: w/gbi',
#  'beach/water rec area violation',
#  'beg/solicit purchase of liquor',
#  'begging',
#  'begging in food/drink establishment',
#  'bell gardens municipal code',
#  'bench warr/fail to appear on fel charge',
#  'bench warr/fail to appear on misd charge',
#  'bench warrant issued',
#  'bench warrant/fail to appear',
#  'benefit by false financial statement',
#  'beverly hills municipal code',
#  'beyond parental control',
#  'bicyclist allow rider on other than seat',
#  'bigamy',
#  'bike headlight/etc viol',
#  'billiards w/o permit',
#  'birds/mammals possess open seas',
#  'blocking free movement',
#  'body harm/death on elder/dependent adult45',
#  'bond surrender',
#  'bootleg recordings w/prior',
#  'brandish f/arm replica at occupant of veh',
#  'brg/send/poss cntl sub/weapn/etc,jh/camp',
#  'bribe po amounting to grand theft',
#  'bribe po amounting to petty theft',
#  'bribe public officer under $400',
#  'bribery exec officer/employee ask/receive',
#  'bribery of an executive officer',
#  'bring cntl sub/etc jail',
#  'bring drug/drug paraphernalia:jail/prison',
#  'bring drugs into prison',
#  'bring kidnapped person into state',
#  'bring possess weapon into courthouse',
#  'bring stolen property into state',
#  'bring/poss f/arm in crtrm/crthse/crt bldg',
#  'bring/poss knife in crtrm/crthse/crt bldg',
#  'bring/poss loaded firearm on schl ground',
#  'bring/poss weapon into courthouse',
#  'bring/possess firearm on school grounds',
#  'bring/send narc/cont subs/alcohol to jail',
#  'bring/send/poss deadly weapon in jail',
#  'build false compartmt in veh:store c/sub',
#  'build fires on posted property',
#  'burbank municipal code',
#  'burglary',
#  'burglary from vehicle',
#  'burglary:first degree',
#  'burglary:second degree',
#  'business regs',
#  'buy veh for resell w/knowledg of fraud id',
#  'buy/sell compu chip/panel,$400+w/id remov',
#  'buy/sell prop w/id removed, < $400',
#  'buy/sell prop w/id removed, > $400',
#  'buy/sell/possess vehicle with altered num',
#  'bypass meter to steal gas',
#  'cafe entertainment viol',
#  'carjacking',
#  'carry away timber/wood fr land of anothr',
#  'carry conceal weapn in veh w/pr convictn',
#  'carry conceal weapn in veh w/pr fel convi',
#  'carry conceald stolen wpn',
#  'carry concealed dirk or dagger',
#  'carry concealed exploxive substance',
#  'carry concealed on person dirk or dagger',
#  'carry concealed weapon in vehicle',
#  'carry concealed weapon in vehicle w/o lic',
#  'carry concealed weapon on person w/o lic',
#  'carry concealed weapon on person/veh',
#  'carry firearm w/narcotics',
#  'carry load f/arm:pr fel',
#  'carry load firearm/narcotics',
#  'carry load firearm/not law poss',
#  'carry loaded f/arm prson/heh public place',
#  'carry loaded f/arm w/int commit felony',
#  'carry loaded f/arm with int to commit fel',
#  'carry loaded firear w/prior felony',
#  'carry loaded firearm in public place',
#  'carry loaded firearm in vehicle',
#  'carry loaded firearm prohibited/etc',
#  'carry loaded firearm: special prs',
#  'carry loaded firearm:gang member',
#  'carry loaded handgun: not owner',
#  'carry stolen loaded f/arm',
#  'carry stolen loaded firearm',
#  'carry switchblade knife upon person',
#  'carry unloaded f/arm that is not handgun',
#  'carry unloaded h/gun in public/proh area',
#  'carry unloaded h/gun in veh his/her poss',
#  'carrying a concealed weapon',
#  'carrying concealed weapon on person',
#  'carrying concealed weapon upon person',
#  'carrying concealed weapon within vehicle',
#  'carrying knife in public view',
#  'carrying loaded firearm',
#  'carson municipal code',
#  'cary load f/arm:pub:s/cir',
#  'cause elder/dependent adult:harm/death',
#  'cause harm/death of elder/depend adult',
#  'cause injury/death of guide/etc dog',
#  'cause veh accident to present false claim',
#  'cause/etc riot:urge destruct property/etc',
#  'ccw in veh w/pr fel conv',
#  'ccw:crim st gang:active',
#  'ccw:prohib/unlawful poss',
#  'certificate required to operate carrier',
#  'change lanes/laned roadway when safe',
#  'change/alter/etc firearm markings',
#  'charter a carrier w/o permit',
#  'chg/alter/remov/obliterate id marks f/arm',
#  'child stealing',
#  'child under 5 severe physical abuse',
#  'circulate intiative/petition/false names',
#  'civil contempt',
#  'climb on electrical power poles/towers',
#  'closed area-mtn fire dist regs',
#  'coin op music machine w/o lic',
#  'comm/mental insane to stand trial',
#  'commerce municipal code',
#  'commercial bribery: bribe exceeds $1,000',
#  'commercial burglary',
#  'commercial vehicle speeding',
#  'commission of crime while armed',
#  'commit oral copulation w/force/viol/etc',
#  'commit sodomy w/force/violence/ect',
#  'communicate w/prisoner w/o consent',
#  'communication w/reformatory inmate',
#  'compound/conceal felony not capitl offens',
#  'compton municipal code',
#  'conceal persn from writ of habeas corpus',
#  'concealed firearm in car',
#  'cond business aftr permit suspend/revok',
#  'conduct dance w/o permit',
#  'conducting business w/o a license',
#  'confine animal w/inadequate exercise area',
#  'consiracy to commit murder',
#  'consp:commit act inj pub/obstruct justice',
#  'consp:commit act inj to pub/obstr justice',
#  'conspiract sell controlled subst',
#  'conspiracy',
#  'conspiracy - theft of property',
#  'conspiracy to commit a crime',
#  'conspiracy to commit any crime',
#  'conspiracy to defraud/cheat',
#  'conspiracy to falsely charge/arrest',
#  'conspiracy to prevent/dissuade wit/victim',
#  'conspiracy to purchase subst',
#  'conspiracy: adw/not firearm/ w/gbi',
#  'conspire sell/transprt cont subs',
#  'conspire to assault with firearm',
#  'conspire to commit grand theft',
#  'conspire to mfg controlled subs',
#  'conspire:ake statement: claim',
#  'conspire:fake stmnt:claim',
#  'consume/purchase alcoholic bev by minor',
#  'cont pattern of unlawful disruption schl',
#  'contact minor for sexual offense',
#  'contempt of court',
#  'contempt of court - disobey court order',
#  'contempt of court - gang act injunction',
#  'contempt of court - presence referee/jury',
#  'contempt of court - resisting court order',
#  'contempt of court -disobey gang injunction',
#  'contempt of court:disobey court order/etc',
#  'continuous sexual abuse against child',
#  'contracting w/o a license',
#  'contracting w/o lic during emergency',
#  'contracting w/o license',
#  'contribute to delinquency of minor',
#  'contributing to delinquency of minor',
#  'convert real property < $100',
#  'convert real property > $100',
#  'convey/sell personal id info w/intent defr',
#  'convey/trans/personal id info w/int defrau',
#  'convicted viol felon refus leave property',
#  'convicted viol felon refuse leave property',
#  'corporal injury on child',
#  'corporal injury on spouse/cohabitant/etc',
#  'corporal injury to child',
#  'counsel/aid in misdemeanor',
#  'counterfeit/forge/alter fare media',
#  'counterfeit/forge/alter transp fare media',
#  'counterfeit/poss 3+countrfeit presc blank',
#  'counterfeiting - punishment',
#  'counterfeiting gold/silver coins/bars/etc',
#  'covina municipal code',
#  'crim store f/arms access to child 1st deg',
#  'crimes against children/lewd/lascivious',
#  'criminal contempt',
#  'criminal threats',
#  'crimnl storage f/arm access child 1st deg',
#  'crmnl storage f/arm access chile 1st deg',
#  'cros in xwalk:prohib sign',
#  'cross lare or cone pattern',
#  'cruel to child likely to prod gbi/death',
#  'cruel to chld:pos inj/dth',
#  'cruelty',
#  'cudahy municipal code',
#  'cultivate >6 marij plants viol envrnt law',
#  'cultivating <6 marijuana plants',
#  'culver city municipal code',
#  'curfew',
#  'curfew - juv only',
#  'curfew violation',
#  'cutting down/destroy/inj standing timbr',
#  'damage jail/etc ($400+)',
#  'damage jail/etc ($400-)',
#  'damage jail/prison',
#  'damage property',
#  'damage/etc property to viol civel rights',
#  'damage/injure aircraft',
#  'damaging or removing highway signs',
#  'damaging/removing fences/gates/signs',
#  'dang drug:use mnr:agent',
#  'danger of leading immoral life',
#  'dealer employing unlicensed salesman',
#  'dealer failing to refund excess fees',
#  'dealer not determining ownership',
#  'dealing in secondhand goods w/o license',
#  'deface property',
#  'deface/damage personal property',
#  'deface/damage property <$400',
#  'deface/damage/etc prop<$400w/prev conv',
#  'defraud inkkeeper by non-payment < $400',
#  'defraud innkeeper by non-payment > $400',
#  'defraud innkeeper/etc by force/etc($400-)',
#  'demand immediate appear before magistrate',
#  'dependent adult neglect/abuse',
#  'deposit of hazardous waste',
#  'deposit offensive subs,public assembly',
#  'depositing non-combustible rubbish',
#  'deprive custody/visit in viol of crt ord',
#  'description non-serialized object',
#  'desert child < 14 yrs w/intent to abandon',
#  'desertion',
#  'dest evid/ownership of logs/lumber/wood',
#  'destroy evid/ownership of wreck property',
#  'destroy posted signs',
#  'destroy property',
#  'destroy property valued less than $1,000',
#  'destroy property valued less than $1000',
#  'destroy/conceal documentary evidence',
#  'destructive device near any public place',
#  'destructive device near certain places',
#  'destructive device near passenger vessel',
#  'destructive device near private habitation',
#  'develop/dupl film/etc depictng minor',
#  'develop/dupl film/etc depictng minor w/pr',
#  'devices on front windows/obstruct view',
#  'discharge bb device in grossly neg manner',
#  'discharge firearm from vehicle',
#  'discharge firearm from vehicle at person',
#  'discharge firearm in public',
#  'discharge firearm in school zone',
#  'discharge fireworks w/likelihood of inj',
#  'discharge laser at aircraft',
#  'discharge wpn - cty',
#  'dischrg firearm/unoccupy veh/uninhab bldg',
#  'dischrg sewage/other waste,cause pollutn',
#  'disconnect/turn back odometer',
#  'dismissed student/employee on campus',
#  'disobey court order w/prior',
#  'disobey domestic relations court order',
#  'disobey domestic relations crt order w/pr',
#  'disobey domstc relatns crt order w/prior',
#  'disobey domstc relatns crt ordr w/pr',
#  'disobey fireman/public officer',
#  'disobey restrictions of license',
#  'disobey subpoena/refuse to testify',
#  'disobey traffic control device',
#  'disord conduct:lodge w/o consent',
#  'disord conduct:loiter/etc priv property',
#  'disord conduct:ui/drug, alcohol',
#  'disorderly conduct:lodge without consent',
#  'disorderly conduct:peek into inhab bldg',
#  'disp/etc dang drug/device',
#  "display another's id card",
#  'display false disabled person placard',
#  'display false license plate on vehicle',
#  'display of permit required',
#  'display/poss/etc firearms knives weapons',
#  'disply canc/revok/susp/etc real est lic',
#  'disregard safety:evade po',
#  'disruptive entry of schl aftr ask leave',
#  'disruptive presence at school',
#  'distr/exhibit obscene matr depict minr<18',
#  'distr/exhibit/etc harmful matter to minr',
#  'distribute harmful matter to minor on int',
#  'distribute image w/intent cause distress',
#  'distribute unsolicited tobacco',
#  'disturb religious meeting',
#  'disturbance of public meeting/assembly',
#  'disturbing religious meetings',
#  'disturbing the peace',
#  'disturbing the peace at university',
#  'diver funds for service/labor/etc >$1000',
#  'diversion of funds for service/labor/etc',
#  'dlr fail rpt prop:pd/so',
#  'dog on public beach',
#  'dog tags required',
#  'door to door sell/sol 2100/0800',
#  'downey municipal code',
#  'draining oil on street',
#  'draw water from closed works',
#  'draw/exhibit f/arm on day care center/etc',
#  'draw/exhibit imitation firearm',
#  'drawing/exhibiting laser scope',
#  'drink alcoholic beverage in veh on hwy',
#  'drinking alcohol',
#  'drinking alcohol*******',
#  'drinking in public',
#  'drinking in public***',
#  'driv veh on divided hghwy left of barrier',
#  'driv wrong way on freeway cause inj/death',
#  'drive against traffic/one-way street',
#  'drive in excess of 100 mph',
#  'drive on private property w/o consent',
#  'drive priv suspend/revkd after prior offn',
#  'drive restrict dui w/in 5 years prior off',
#  'drive sus/rev dui w/in 5 yrs prior offns',
#  'drive suspended for reckless driving w/pr',
#  'drive thru closed r/r crossing gate',
#  'drive veh w/o city permit',
#  'drive w/lic suspend/rev 4 reckless drivg',
#  'drive w/lic suspend/revoke 4 drugs/alcohl',
#  'drive w/lic suspend/revoke 4 other reason',
#  'drive w/o interlock dev',
#  'drive w/susp/rev lic w/injury collision',
#  'drive w/suspended/revoked license',
#  'drive with knowledge that lic susp/rev',
#  'drive/ride/etc along railroad track',
#  'drive/take law enf/fire veh w/o consent',
#  'drive/take veh w/o consent aftr prior con',
#  'driver fail to use child restraint system',
#  'driver/owner permit unloaded f/arm in veh',
#  'driving commercial veh w/.04 blood/alcohl',
#  'driving motorcycle w/o wearing a helmet',
#  'driving on center divider',
#  'driving on sidewalk',
#  'driving w/defectiv windshield/rear window',
#  'driving w/knowledge of lic restrictions',
#  'driving w/o lights after dark',
#  'driving w/obstructed view',
#  'driving with knowledge of suspended lic',
#  'driving with suspended license',
#  'drug offender remain in school zone',
#  'drug paraphenalia/hype syringe mnr prson',
#  'drunk driving',
#  'drunk driving .10 or above',
#  'drunk driving addict drive vehicle',
#  'drunk driving alcohol/drugs',
#  'drunk, alcohol',
#  'dui .08 alcohol causing injury',
#  'dui alcohol causing injury',
#  'dui alcohol/0.08 w/prs',
#  'dui alcohol/drug w/priors',
#  'dui alcohol/drugs on bicycle',
#  'dui boat or watercraft',
#  'dui drugs',
#  'dui of a drug causing injury',
#  'dui of alcohol & drug',
#  'dui of alcohol & drug causing injury',
#  'dui of any drug',
#  'dui of comb drug & alcohol influence',
#  'dui w/prior sepc convictions',
#  'dui w/prior spec convictions',
#  'dui w/prior specific convictions',
#  'dui with prior convictions',
#  'dui with prior convitions',
#  'dui/boat or watercraft',
#  'dump offensive matter',
#  'dump rock:pub:comercl amt',
#  'dump rocks/dirt',
#  'dump waste in water/on shore',
#  'dump waste matter',
#  'dump waste/rocks/etc',
#  'dump/etc garbage/refuse:publ street/prop',
#  'dump/etc waste in commercial quantities',
#  'dump/etc waste/garb/etc',
#  'dumping',
#  'dumping into public sewer sanitary fac',
#  'dup veh master key w/o maint id of buyer',
#  'eavesdropping',
#  'el monte municipal code',
#  'elder adult neglect/abuse',
#  'elder/dependent adult theft: by caretaker',
#  'embezzle of prop by bailee/tenant/lodger',
#  'embezzle of prop by public/p.o. >$400',
#  'embezzle of property by carrier',
#  'embezzle of property by carrier >$400',
#  'embezzle prop:bailee/tenant/lodger >$400',
#  'embezzle prop:trustee/bankr/merchant/etc',
#  'embezzle prop:trustee/bankr/merchant>$400',
#  'embezzle rented/leased vehicle',
#  'embezzle/rented/leased vehicle',
#  'embezzlement',
#  'embezzlement >$400',
#  'embezzlement by collector of accts/debts',
#  'embezzlement by po for personal use',
#  'embezzlement of construction funds',
#  'embezzlement of prop und lease/lien >$400',
#  'embezzlement of prop under lease/lien',
#  'embezzlement of property by employee',
#  'embezzlement of property by employee>$400',
#  'embezzlemt of prop proceed by debtor>$400',
#  'employ minor where alcohol sold',
#  'engage in business without a license',
#  'engage in loud/boisterous/unruly behavior',
#  'engage/solicit sex for money/etc',
#  'engaging in bookmaking/pool selling',
#  'enhancement - vandalism w/prior',
#  'enhancement - vandalism w/priors',
#  'enhancement: gbi in commission of crime',
#  'enter disaster area aftr notic evac',
#  'enter land under cultivatn w/o permission',
#  'enter place of employment before safe',
#  'enter without paying admission',
#  'enter/occupy property w/o consent',
#  'enter/remain on posted property',
#  'entice minor/virgin female for prost',
#  'erect unlawful sign on pub prop',
#  'erect/use tent/shelter on beach',
#  'escape jail whil charge w/fel:force/viol',
#  'escape jail/etc charged w/misd:force/viol',
#  'escape jail/etc chg w/misd-force/viol',
#  'escape jail/etc while charged with felony',
#  'escape jail/etc while charged with misd',
#  'escape jail:charged with fel:force/viol',
#  'escape/att from cust w/forc/etc cause sbi',
#  'escape/attempt escape fr po',
#  'escape/attempt escape fr po cause injury',
#  'escape/attempt escape from custody',
#  'escort without permit',
#  'evade pay admsn fee',
#  'evade pay fare on publc transp system',
#  'evade payfare publc/subsidize transp sys',
#  'evade po:disregard safety',
#  'evade railroad fare',
#  'evade taxes on cigarettes/etc',
#  'evading a peace officer w/death/gbi',
#  'evading arrest',
#  'evading peace officer',
#  'evading po/drive in reckless manner',
#  'evading police officer/wrong way driver',
#  'evading taxi fare',
#  'evasion of fare',
#  'evasion of fare w/priors',
#  'evidence of financial responsibility req',
#  'ex-felon on/adjacent to prison grounds',
#  'exceed allowable weight',
#  'exceed speed on highway',
#  'exceeding allowable weights for axels',
#  'exceeding written estimates',
#  'execute scheme obtain mney/prop medi-cal',
#  'execute scheme obtain money/prop medi-cal',
#  'exhibit deformities for hire',
#  'exhibit firearm in presence of po',
#  'exhibit firearm with great bodily inj',
#  'exhibit firearm/dead weapn resist arrest',
#  'exhibit/draw deadly weapon not a firearm',
#  'exhibit/draw deadly weapon/firearm',
#  'exhibit/draw firearm',
#  'exhibit/draw firearm presence reserve po',
#  'exhibit/draw firearm w/gbi',
#  'expectorat on publc transp system fac/veh',
#  'expired tabs/fail display',
#  'extortion',
#  'extortion by threatening letter',
#  'extortion w/threat of injury',
#  'extortion w/threatening letter',
#  'extradition of parole/probation violator',
#  'fail 2 poss commercial fishing license',
#  'fail carry sec guard firearm permit',
#  'fail carry sec guard registration card',
#  'fail carry security guard regi card',
#  'fail comply court ord:veh',
#  'fail correct or deliver correctn of viol',
#  'fail disclose origin of recordg/1000+art',
#  'fail disclose origin of recording',
#  'fail disclose origin or recording',
#  'fail furnish proof of financial respnsbty',
#  'fail maint record sale of lock pick/etc',
#  'fail obey order of juvenile court',
#  'fail oper vapor rcovy systm gas cargotank',
#  'fail protect child from sexual abuse',
#  'fail reg gain/lv resid',
#  'fail reg/etc sex off/pr',
#  'fail to carry id for firearm/duty',
#  'fail to carry valid baton permit',
#  'fail to comply w/registration requrmnts',
#  'fail to comply with labor code',
#  'fail to conduct proper operations',
#  'fail to control mischievous animal',
#  'fail to disclose origin of recording',
#  'fail to disclose origin of recording w/pr',
#  'fail to disclose origin of recordings',
#  'fail to disclose recording origin',
#  'fail to display food facility permit',
#  'fail to drive right of roadway',
#  'fail to exchange info following accident',
#  'fail to exhibit fish on demand of warden',
#  'fail to file tax w/intent to defraud',
#  'fail to give written promise to appear',
#  'fail to keep f/arm inaccessible to child',
#  'fail to keep proper business records',
#  'fail to keep required records',
#  'fail to maint sep living quarters',
#  'fail to maintain adequate muffler',
#  'fail to maintain headlamp',
#  'fail to maintain motel register',
#  'fail to make proper stop at intersection',
#  'fail to notify dmv of vehicle transfer',
#  'fail to obey fireman',
#  'fail to obey peace officer',
#  'fail to obey restraining order',
#  'fail to obey traffic signs/signals',
#  'fail to pass to left safely',
#  'fail to present dl/financial respon info',
#  'fail to present id',
#  'fail to provide proof of residence',
#  'fail to provide required information',
#  'fail to provide true registration info',
#  'fail to reg for sale/etc of piperidine',
#  'fail to register as cntl subs offender',
#  'fail to register as felony sex offender',
#  'fail to register as misd sex offender',
#  'fail to register as sex offender',
#  'fail to register w/campus police/etc',
#  'fail to register w/city pd/sheriff/etc',
#  'fail to register w/prior',
#  'fail to report serl secondhand property',
#  'fail to secure payment compensation',
#  'fail to stop at r/r crossing signal',
#  'fail to stop/flashing red light',
#  'fail to update registration',
#  'fail to update registration w/prior',
#  'fail to use child restraint system',
#  'fail to yield',
#  'fail to yield/pedestrian in crosswalk',
#  'fail to yield:ped:xwalks',
#  'failure to appear',
#  'failure to care for aminal',
#  'failure to carry registration in vehicle',
#  'failure to collect/pay tax',
#  'failure to display liquor license',
#  'failure to file change of address',
#  'failure to give written notice',
#  'failure to maintain lighting equipment',
#  'failure to maintain two stoplamps',
#  'failure to notify doj of firearm sale',
#  'failure to obey officer',
#  'failure to pay fine/warrant',
#  'failure to provide for after ajudication',
#  'failure to provide for minor child',
#  'failure to register after convict arson',
#  'failure to register as an arson offender',
#  'failure to register as sex offender',
#  'failure to sign citation/produce id',
#  'failure to transfer registration',
#  'failure to update registration',
#  'failure to use seatbelts',
#  'failure to wear seatbelt',
#  'false affidavit as to testimony',
#  'false application for aid',
#  'false certification of medical condition',
#  'false checks/rec/cert/etc',
#  'false eligibility statement',
#  'false evidence of registration',
#  'false fire alarm resulting in gbi',
#  'false id to peace officer',
#  'false identification to peace officer',
#  'false imprismnt of elder/dependt adult',
#  'false imprison:viol/etc',
#  'false imprisonment',
#  'false information/i.d. to pawnbroker/etc',
#  'false license plates',
#  'false personate:spec circ',
#  'false personation in suit of prosecution',
#  'false personation to get money/property',
#  'false personation to make other liable',
#  'false personation to post bail/surety',
#  'false personation to record document',
#  'false personation:get money/property>$400',
#  'false personation:sp circ',
#  'false proof:finance resp',
#  'false report of bomb to any peace officer',
#  'false report of bomb to any person',
#  'false report of bomb to public agency/bus',
#  'false report of crime',
#  'false report of criminal offense to po',
#  'false report of emergency',
#  'false repres self as alarm company lic',
#  'false representation of self',
#  'false rpt crime to employee/design agency',
#  'false rpt of criminal offense to any po',
#  'false rpt of emergency result injury/gbi',
#  'false rpt of veh theft w/intent to deceiv',
#  'false rpt:poisn/harmfu sub food/drink/etc',
#  'false statement regarding aid',
#  'false statement to obtain afdc',
#  'false statement/immigration matter',
#  'false statements regarding aid',
#  'false statements to dmv or chp',
#  'false statements to obtain aid',
#  'false voter registration',
#  'false/fraud claims-vehicle loss/damage',
#  'false/fraud statemt to discourage claim',
#  'false/misleading advertising statements',
#  'falsely obtain/possess dmv/documents',
#  'falsify disabled person placard',
#  'fel/etc rec/etc f/arm/amo',
#  'felon purchases/owns/poss body armor',
#  'felony for fourth dui',
#  'felony prostitution',
#  'fight at college/university/school',
#  'fight/challenge in public place',
#  'fight/etc in pubilc place',
#  'fil to register as sex offender',
#  'file false docu for title/etc on real est',
#  'file false document/county record',
#  'file false tax return',
#  'file with labor commission',
#  'financial dependent adult abuse',
#  'financial elder abuse',
#  'fine and/or pris-fraud cl $400 or less',
#  'fine and/or pris-fraud claim over $400',
#  "fire area/oprte veh s/in 300'",
#  'fire regulation',
#  'firearm w/narcotics',
#  'firearm/firework/airgun/etc in park',
#  'fireworks regulation',
#  'fishing w/o a license',
#  'fix evid:harm safety ofcr',
#  'flash incarceration',
#  'food waste disp. etc viol',
#  'forcible entry and detainer',
#  'forcible entry w/property damage',
#  'forcible oral copulation',
#  'foreclosure fraud',
#  'forge name on access card',
#  'forge/alter narcotic prescription',
#  'forge/etc prescription',
#  'forge/make/use of access card to defraud',
#  'forger exceed $950 not check/bond, etc',
#  'forgery',
#  'forgery check/bon, etc not > $950',
#  'forgery check/bond, etc not > $950',
#  'forgery check/bond, etc. not > $950',
#  'forgery check/bond, etc. not >$950 sp/conv',
#  'forgery exceeding $950 check/bond etc',
#  'forgery exceeding $950 in value',
#  'forgery exceeding $950 not check/bond etc',
#  "forgery/counterfeit driver's lic/id card",
#  'forgery/counterfeit public/corporate seal',
#  'fortune telling',
#  'fraud obt ins:reduce rate',
#  'fraud telephone/telegraph service',
#  'fraud to obt insurance at a reduced rate',
#  'fraud use of computer to obt $/prop/data',
#  'fraud use of telephone/telegraph,>$400',
#  'fraud use phone/telegraph service',
#  'fraud/forge w/intent to obtain aid',
#  'fraud:acc dev:goods $1k+',
#  'fraudulent computer access',
#  'fraudulent conveyances of property',
#  "fraudulent use of contractor's license",
#  'fraudulent/false info to obt med assist',
#  'fraudulently display id card',
#  'front light & reflector white/amber',
#  'ft/reg/etc:fel sex off/pr',
#  'fta after bail release on felony',
#  'fta after o.r. release on felony',
#  'fta after o.r. release on misdemeanor',
#  'fta after post bail, fine',
#  'fta after written promise',
#  ...]

# %%
# Vamos filtrar somente prisões por marijuana. Vamos usar 'mari' na pesquisa pois pode haver abreviações.
[x for x in lista_prisoes if 'mari' in x]
# Out:
# ['attempt - sell/furnish/etc marijuana',
#  'attempt to poss < 28.5 grams of marijuana',
#  'cultivate >6 marij plants viol envrnt law',
#  'cultivating <6 marijuana plants',
#  'furnishing marijuana to minor over 14 yrs',
#  'give/transport/etc < 28.5 grams marijuana',
#  'induce/etc minor to use/sell marijuana',
#  'minor poss 28.5+ grams marijuana/school',
#  'minor poss < 28.5 grams marijuana/school',
#  'poss for sale of marijuana to a minor',
#  'poss marijuana for sale w/two/more priors',
#  'poss marijuana or concentrated cannabis',
#  'poss of more than 28.5 grams of marijuana',
#  'poss open cont/packg marij drivr/passnger',
#  'poss/sale marij ovr 21 employ per 20/belw',
#  'poss/smoke/ingest marij school/daycare/yc',
#  'possess 28.5 grams or less of marijuana',
#  'possess 28.5 grams or less of marijuana**',
#  'possess marijuana for sale',
#  'possess marijuana for sale under age 18',
#  'possess of marijuana while driving veh',
#  'possession marijuana for sale',
#  'possession of marijuana in school',
#  'sale/offer to sell/transport marijuana',
#  'sale/trans >28.5g marijuana or >4g',
#  'sale/transport marijuana to a minor',
#  'sale/transport marijuana w/priors',
#  'sell/furnish/etc marij/hash over 1 oz',
#  'smoke marij loc where smoke tobacco proh',
#  'smoke/ingest marijuana in public place',
#  'transport/etc marijuana',
#  'transport/sell/furnish/etc marijuana',
#  'unlawfully plant/cultivate/etc marijuana',
#  'use minor under 14 trans/sell marijuana']

# %%
# Qual o total de prisões que contém a palavra 'mari'?
len([x for x in lista_prisoes if 'mari' in x])
# Out:
# 34

# %% [markdown]
# Existem 34 diferentes tipos de prisões por causa de maconha que tratam de cultivar, possuir, vender, fumar em público e lidar com menores.

# %%
# Criamos uma lista com as razões de prisão por maconha
prisoes_maconha = [x for x in lista_prisoes if 'mari' in x]

# %%
# Criamos uma coluna no dataframe que identifica as prisões se elas estiverem relacionadas à maconha
df_prisoes['marijuana_related'] = df_prisoes['Charge Description'].map(lambda x: x if x in prisoes_maconha else np.NaN)

# %%
# Visualizamos uma amostra de dados
df_prisoes.head()
# Out:
#    Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  Age  \
# 0  200110044  2020-03-27  2125.0        1    Central                 142   20
# 1  200110045  2020-04-01  1800.0        1    Central                 166   44
# 2  200110271  2020-03-08  1545.0        1    Central                 166   61
# 3  201908605  2020-04-08  1530.0       19    Mission                1987   33
# 4  191811472  2019-05-03  1700.0       18  Southeast                1802   23
#
#   Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 0        F            W               13.0      Prostitution/Allied
# 1        F            H               18.0               Drunkeness
# 2        M            B               18.0               Drunkeness
# 3        M            H                NaN                      NaN
# 4        F            B                NaN                      NaN
#
#   Arrest Type Code       Charge     Charge Description  \
# 0                M     647(B)PC           prostitution
# 1                M  41.27(C)LAM  drinking in public***
# 2                M  41.27(C)LAM  drinking in public***
# 3                M   25620(A)BP                    nan
# 4                M    653.22 PC                    nan
#
#                                   Address                     Cross Street  \
# 0  400 S  FIGUEROA                     ST                              NaN
# 1         WINSTON                      ST  SAN PEDRO                    ST
# 2                                     6TH                       SAN JULIAN
# 3                                 WOODMAN                            CHASE
# 4                                    91ST                         FIGUEROA
#
#                Location  latitude  longitude marijuana_related
# 0   [34.0535, -118.256]   34.0535  -118.2560               NaN
# 1  [34.0421, -118.2469]   34.0421  -118.2469               NaN
# 2  [34.0428, -118.2461]   34.0428  -118.2461               NaN
# 3   [34.228, -118.4344]   34.2280  -118.4344               NaN
# 4  [33.9543, -118.2827]   33.9543  -118.2827               NaN

# %% [markdown]
# Valores nulos foram gerados quando não se trata de uma prisão relacionada a maconha. Vamos contar o que NÃO é valor nulo.

# %%
len(df_prisoes[~df_prisoes['marijuana_related'].isnull()])
# Out:
# 20673

# %% [markdown]
# Temos 20.673 prisões por razões relacionadas à maconha!

# %%
# Removendo os registros que não correspondem a prisões relacionadas a maconha.
df_prisoes = df_prisoes[~df_prisoes['marijuana_related'].isnull()]

# %%
# Shape
df_prisoes.shape
# Out:
# (20673, 20)

# %%
# Visualizamos uma amostra de dados
df_prisoes.head()
# Out:
#       Report ID Arrest Date    Time  Area ID  Area Name  Reporting District  \
# 340     5568617  2019-03-09  2015.0        6  Hollywood                 646
# 342     5568629  2019-03-09  2015.0        6  Hollywood                 646
# 983     5607178  2019-04-21  2115.0        7   Wilshire                 702
# 1249  200608837  2020-03-17  2200.0        6  Hollywood                 646
# 1255  200608903  2020-03-19  2320.0        6  Hollywood                 645
#
#       Age Sex Code Descent Code  Charge Group Code Charge Group Description  \
# 340    29        M            O               16.0       Narcotic Drug Laws
# 342    25        M            B               16.0       Narcotic Drug Laws
# 983    42        M            B               16.0       Narcotic Drug Laws
# 1249   21        F            B               16.0       Narcotic Drug Laws
# 1255   25        M            W               16.0       Narcotic Drug Laws
#
#      Arrest Type Code       Charge                         Charge Description  \
# 340                 F      11359HS              possession marijuana for sale
# 342                 F      11359HS              possession marijuana for sale
# 983                 F   11359(D)HS  poss/sale marij ovr 21 employ per 20/belw
# 1249                I  11362.3A1HS     smoke/ingest marijuana in public place
# 1255                I  11362.3A1HS     smoke/ingest marijuana in public place
#
#                               Address                     Cross Street  \
# 340                          CHEROKEE                        HOLLYWOOD
# 342                          CHEROKEE                        HOLLYWOOD
# 983   MELROSE                      AV  FAIRFAX                      AV
# 1249                        HOLLYWOOD                             VINE
# 1255                        HOLLYWOOD                         HIGHLAND
#
#                   Location  latitude  longitude  \
# 340    [34.1016, -118.335]   34.1016  -118.3350
# 342    [34.1016, -118.335]   34.1016  -118.3350
# 983   [34.0838, -118.3614]   34.0838  -118.3614
# 1249  [34.1016, -118.3267]   34.1016  -118.3267
# 1255  [34.1016, -118.3387]   34.1016  -118.3387
#
#                               marijuana_related
# 340               possession marijuana for sale
# 342               possession marijuana for sale
# 983   poss/sale marij ovr 21 employ per 20/belw
# 1249     smoke/ingest marijuana in public place
# 1255     smoke/ingest marijuana in public place

# %%
# Salva o dataframe de prisões em um arquivo csv
df_prisoes.to_csv('dados/df_prisoes.csv')

# %% [markdown]
# ### Extração e Limpeza dos Dados - Dataset 4
#
# Iremos calcular a distância entre todas as prisões por maconha e as escolas do Distrito Escolar Unificado de Los Angeles (LAUSD), examinando o número de prisões por maconha a menos de 800 quilômetros de uma escola a cada ano.
#
# Os dados estão disponíveis neste endereço:
#
# http://www.lausd.k12.ca.us/lausd/offices/bulletins/
#
# E este é o arquivo que precisamos:
#
# http://www.lausd.k12.ca.us/lausd/offices/bulletins/lausdk12.tab
#
# Dados já disponiveis.

# %%
# Carregamos o arquivo com dados de escolas de LA
df_escolas = pd.read_csv('dados/lausdk12.tab', sep = '\t')

# %%
# Shape
df_escolas.shape
# Out:
# (1386, 14)

# %%
# Visualizamos uma amostra de dados
df_escolas.head()
# Out:
#    Cost Center Code  Legacy Code  \
# 0           1585701         5857
# 1           1585702         5858
# 2           1583601         5836
# 3           1708201         7082
# 4           1588401         5884
#
#                                               School                Address  \
# 0                            107th Street Elementary         147 E 107th St
# 1  107th Street Elementary Science/Tech/Eng/Arts/...         147 E 107th St
# 2                            109th Street Elementary  10915 S Mc Kinley Ave
# 3                             10th Street Elementary        1000 Grattan St
# 4                            112th Street Elementary        1265 E 112th St
#
#           City State  Zip Code     Telephone           Fax Grades Calendar  \
# 0  Los Angeles    CA     90003  323-756-8137  323-779-6942   K- 5    1 Trk
# 1  Los Angeles    CA     90003  323-756-8137  323-779-6942   1- 5    1 Trk
# 2  Los Angeles    CA     90059  323-756-9206  323-755-2307   K- 5    1 Trk
# 3  Los Angeles    CA     90015  213-380-8990  213-480-6732   1- 5    1 Trk
# 4  Los Angeles    CA     90059  323-567-2108  323-567-2611   K- 5    1 Trk
#
#   Local District           Board District File Build Date
# 0              S  7-Dr Richard A Vladovic      2020-05-14
# 1              S  7-Dr Richard A Vladovic      2020-05-14
# 2              S  7-Dr Richard A Vladovic      2020-05-14
# 3              C          2-Monica Garcia      2020-05-14
# 4              S  7-Dr Richard A Vladovic      2020-05-14

# %% [markdown]
# Vamos combinar as colunas `Address`, `City`, `State`, `CEP` para criar uma variável `complete_address` que será usada para obter as coordenadas de cada escola, que usaremos na geolocalização.

# %%
# Combinando dados de endereços para gerar as coordenadas mais tarde
df_escolas['complete_address'] = df_escolas['Address'] +' '+ df_escolas['City'] +' '+ df_escolas['State'] +' '+ df_escolas['Zip Code'].astype(str)

# %%
df_escolas.dtypes
# Out:
# Cost Center Code     int64
# Legacy Code          int64
# School              object
# Address             object
# City                object
# State               object
# Zip Code             int64
# Telephone           object
# Fax                 object
# Grades              object
# Calendar            object
# Local District      object
# Board District      object
# File Build Date     object
# complete_address    object
# dtype: object

# %%
# Deletando colunas que não serão necessárias na nossa análise.
df_escolas = df_escolas.drop(['Address', 'City', 'State', 
                              'Cost Center Code', 'Legacy Code', 'Telephone', 'Fax', 'Calendar',
                              'File Build Date'], 
                             1)

# %%
# Removemos Registros duplicados baseado na localização do endereço completo, se existirem
df_escolas = df_escolas[~df_escolas.duplicated(subset = 'complete_address')].sort_values('complete_address')

# %%
# Reset do índice do dataframe, pois registros podem ter sido removidos
df_escolas.reset_index(drop = True, inplace = True)

# %%
# Shape
df_escolas.shape
# Out:
# (947, 6)

# %%
# Visualizamos uma amostra de dados
df_escolas.head()
# Out:
#                                               School  Zip Code Grades  \
# 0                          Frank Del Olmo Elementary     90004   K- 5
# 1                             10th Street Elementary     90015   1- 5
# 2                    Elementary Community Day School     91311   K- 6
# 3  Cesar E Chavez Learning Academy - Arts/Theatre...     91340   9-12
# 4          San Pedro Senior High Gifted STEAM Magnet     90731   9-12
#
#   Local District           Board District  \
# 0              C          2-Monica Garcia
# 1              C          2-Monica Garcia
# 2             XS    3-Scott M Schmerelson
# 3             NE            6-Kelly Gonez
# 4              S  7-Dr Richard A Vladovic
#
#                                complete_address
# 0  100 N New Hampshire Ave Los Angeles CA 90004
# 1          1000 Grattan St Los Angeles CA 90015
# 2         10001 Jumilla Ave Chatsworth CA 91311
# 3         1001 Arroyo Ave San Fernando CA 91340
# 4             1001 W 15th St San Pedro CA 90731

# %%
# Salva o dataframe de escolas em um arquivo csv
df_escolas.to_csv('dados/df_escolas.csv')

# %% [markdown]
# Neste ponto temos 4 arquivos csv, um para cada dataset após a limpeza. Iremos utilizar esses datasets nos arquivos seguintes.

# %% [markdown]
# # Let's Go Part 2
